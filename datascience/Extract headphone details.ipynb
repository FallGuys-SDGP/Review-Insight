# %%
import os
import json
import gzip
import pandas as pd
from urllib.request import urlopen

# %%
### load the meta data

data = []
with gzip.open('meta_Electronics.json.gz') as f:
    for l in f:
        data.append(json.loads(l.strip()))
    
# total length of list, this number equals total number of products
print(len(data))

# first row of the list
print(data[249])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b668e25269dd> in <module>
#       2
#       3 data = []
# ----> 4 with gzip.open('meta_Electronics.json.gz') as f:
#       5     for l in f:
#       6         data.append(json.loads(l.strip()))
#
# ~\anaconda3\lib\gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      56     gz_mode = mode.replace("t", "")
#      57     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      60         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# ~\anaconda3\lib\gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     171             mode += 'b'
#     172         if fileobj is None:
# ...

# %%
# convert list into pandas dataframe

df = pd.DataFrame.from_dict(data)

print(len(df))
# Out:
# 786445

# %%
##########################################
## CHECK DATA IN PANDAS
##########################################



print ("Total data:", str(df.shape))
df.head(100)
# Out:
# Total data: (786445, 18)
#                                              category  \
# 0   [Electronics, Camera &amp; Photo, Video Survei...
# 1                   [Electronics, Camera &amp; Photo]
# 2   [Electronics, eBook Readers &amp; Accessories,...
# 3   [Electronics, eBook Readers & Accessories, eBo...
# 4   [Electronics, eBook Readers & Accessories, eBo...
# ..                                                ...
# 95  [Electronics, Camera &amp; Photo, Accessories,...
# 96  [Electronics, Computers &amp; Accessories, Tab...
# 97  [Electronics, eBook Readers &amp; Accessories,...
# 98  [Electronics, eBook Readers &amp; Accessories,...
# 99  [Electronics, eBook Readers & Accessories, Cov...
#
#                                                 tech1  \
# 0
# 1
# 2
# 3
# 4
# ..                                                ...
# 95   class="a-keyvalue prodDetTable" role="present...
# 96
# 97   class="a-keyvalue prodDetTable" role="present...
# ...

# %%
df.isnull().sum()
# Out:
# category          0
# tech1             0
# description       0
# fit               0
# title             0
# also_buy          0
# image             0
# tech2             0
# brand             0
# feature           0
# rank              0
# also_view         0
# main_cat          0
# similar_item      0
# date              0
# price             0
# asin              0
# details         838
# dtype: int64

# %%
df=df.dropna(subset=['title'])

# %%
df.shape
# Out:
# (786445, 18)

# %%
product_reviews_hp = df[df["title"].str.contains("headphones|headphone|Headphones|Headphone")]

# %%
product_reviews_hp.shape
# Out:
# (27049, 18)

# %%
product_reviews_hp.isnull().sum()
# Out:
# category         0
# tech1            0
# description      0
# fit              0
# title            0
# also_buy         0
# image            0
# tech2            0
# brand            0
# feature          0
# rank             0
# also_view        0
# main_cat         0
# similar_item     0
# date             0
# price            0
# asin             0
# details         16
# dtype: int64

# %%
product_reviews_hp = product_reviews_hp.drop(['category', 'tech1', 'description', 'fit', 'also_buy', 'tech2', 'also_view', 'main_cat', 'similar_item', 'date', 'details', 'feature', 'rank', 'price'], axis="columns")

# %%
product_reviews_hp = product_reviews_hp[['asin', 'brand', 'image', 'title']]
product_reviews_hp.head(5)
# Out:
#            asin            brand  \
# 8    0132492776  Enter The Arena
# 47   0558835155         Polaroid
# 132  0692206280  Enter The Arena
# 223  0983629269  Enter The Arena
# 229  0985262788  Enter The Arena
#
#                                                  image  \
# 8    [https://images-na.ssl-images-amazon.com/image...
# 47   [https://images-na.ssl-images-amazon.com/image...
# 132  [https://images-na.ssl-images-amazon.com/image...
# 223  [https://images-na.ssl-images-amazon.com/image...
# 229  [https://images-na.ssl-images-amazon.com/image...
#
#                                                  title
# 8    Wireless Bluetooth Headphones Earbuds with Mic...
# 47   Polaroid Pbm2200 PC / Gaming Stereo Headphones...
# 132  Bluetooth Workout Headphones for Running and G...
# 223  Bluetooth Workout Headphones for Running and G...
# 229  Bluetooth Workout Headphones for Running and G...

# %%
product_reviews_hp.to_csv('Headphone details.csv', sep=',', encoding='utf-8', index = False)

# %%
product_reviews_hp.to_json('Headphone details.json')
