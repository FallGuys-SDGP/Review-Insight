# %%
import pickle
import pandas as pd

filePath = '../dataset/amazon_reviews.txt'
df = pd.read_csv(filePath, delimiter='\t')

# %%
df.head(50)
# Out:
#     DOC_ID       LABEL  RATING VERIFIED_PURCHASE        PRODUCT_CATEGORY  \
# 0        1  __label1__       4                 N                      PC
# 1        2  __label1__       4                 Y                Wireless
# 2        3  __label1__       3                 N                    Baby
# 3        4  __label1__       4                 N         Office Products
# 4        5  __label1__       4                 N                  Beauty
# 5        6  __label1__       3                 N  Health & Personal Care
# 6        7  __label1__       4                 N                    Toys
# 7        8  __label1__       4                 Y                  Beauty
# 8        9  __label1__       4                 N  Health & Personal Care
# 9       10  __label1__       1                 N  Health & Personal Care
# 10      11  __label1__       1                 N  Health & Personal Care
# 11      12  __label1__       4                 N                 Kitchen
# ...

# %%
df['LABEL'] = df['LABEL'].replace(['__label1__'], 'Fake')
df['LABEL'] = df['LABEL'].replace(['__label2__'], 'Real')

# %%
df.head(12000)
# Out:
#        DOC_ID LABEL  RATING VERIFIED_PURCHASE PRODUCT_CATEGORY  PRODUCT_ID  \
# 0           1  Fake       4                 N               PC  B00008NG7N
# 1           2  Fake       4                 Y         Wireless  B00LH0Y3NM
# 2           3  Fake       3                 N             Baby  B000I5UZ1Q
# 3           4  Fake       4                 N  Office Products  B003822IRA
# 4           5  Fake       4                 N           Beauty  B00PWSAXAM
# ...       ...   ...     ...               ...              ...         ...
# 11995   11996  Real       3                 Y           Beauty  B0009JQFF6
# 11996   11997  Real       5                 Y               PC  B002HT45WG
# 11997   11998  Real       3                 Y          Jewelry  B000YZM56S
# 11998   11999  Real       4                 Y  Office Products  B0052L7DHA
# 11999   12000  Real       5                 Y          Grocery  B000YV5X98
#
#                                            PRODUCT_TITLE  \
# ...

# %%
df.to_csv('test.txt', sep='\t', encoding='utf-8', index = False',)
# Out:
#   File "<ipython-input-31-e6ab836d04fb>", line 1
#     df.to_csv('test.txt', sep='\t', encoding='utf-8', index = None',)
#                                                                      ^
# SyntaxError: EOL while scanning string literal

# %%
df.to_csv(r'../dataset/amazon_review_updated_label.txt', index=None, sep='\t', mode='a')
