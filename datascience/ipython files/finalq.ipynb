# %%
import pandas as pd
import pickle
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
# filePath = '/content/drive/MyDrive/SDGP/Main/Data Science/Dataset/reviews_only(Sentiment)_cleaned.csv'
filePath = '../dataset/Reviews only (Sentiment) only 20.csv'
df = pd.read_csv(filePath)
# reviewDf = df.drop(['overall', 'vote', 'verified', 'reviewerID', 'asin', 'summary', 'unixReviewTime', 'brand','title'], axis="columns")

# %%
df
# Out:
#                                            reviewText
# 0   I've been using these for over a year now.  Ba...
# 1   I have owned these for over two years and wore...
# 2   I bought these thinking they were the ticket t...
# 3   I've owned these for years. I used to fly two ...
# 4   I love these headphones!! I got these in Narit...
# 5   Work Good. I don't have another reference. You...
# 6   This headphone was my first foray into noise-r...
# 7   Not as immersive and noise-cancelling as other...
# 8   I own these and the Bose Quiet Comfort 2 ($250...
# 9   Sound quality of the headset (noise canceling ...
# 10  I have used the headphones for 2 years -- they...
# 11  I am really satisfied with this purchase. The ...
# 12  This item gets two stars instead of one becaus...
# 13  Sound Quality very good, easy setup and like t...
# 14  These work great for watching tv at night when...
# 15  I bought these at the flea market for 10 dolla...
# 16  Let's make it short story. It extremly difficu...
# 17  I purchased this product because I could never...
# 18  I bought these headphones because I saw other ...

# %%
def breakSentences(word_array):
  sentence_all = []
  for index, row in df.iterrows():
    sentences_with_feature = []
    for sen in sent_tokenize(row['reviewText']):
        l = word_tokenize(sen)
        if len(set(l).intersection(word_array))>0:
            sentences_with_feature.append(sen)
    sentence_all.append(sentences_with_feature)
  list_of_tuples = list(zip(sentence_all)) 
  df_sentences = pd.DataFrame(list_of_tuples,columns = ['reviewText'])
  return df_sentences

# %%
def sentiment(sentenceArray,feature):
  df_audio = sentenceArray
  # df_audio.insert(1, "lab",0)
  
  for index, row in df_audio.iterrows():
#     list_of_tuples = list(zip(row['reviewText'])) 
#     df_sentences = pd.DataFrame(list_of_tuples,columns = [feature+'_sen'])
#     if (row['reviewText'].):
    predictArr=[]
    if(len(row['reviewText'])==0):
        sen = 'NA'
        df_audio.loc[index, feature+'_label'] = sen
    else:
        prdict = loaded_pipeline.predict(row['reviewText'])
        df_audio.loc[index, feature+'_label'] = prdict
#     df_audio_sentences['scores'] = df_audio_sentences[feature+'_sen'].apply(lambda audio_sen: sid.polarity_scores(str(audio_sen)))
#     df_audio_sentences['compound']  = df_audio_sentences['scores'].apply(lambda score_dict: score_dict['compound'])
#     df_audio_sentences[feature+'_label'] = df_audio_sentences['compound'].apply(lambda c: 'pos' if c >=0.5 else ('neu' if c >= -0.5 else 'neg'))
    
#     total = df_sentences['compound'].sum()
#     numRow = df_sentences['compound'].count()
#     averageCompound = float(total/numRow)
    
#     if np.isnan(averageCompound):
#     elif averageCompound >= 0:
#       sen = "pos"
#     elif (averageCompound > -0.25) and (averageCompound < 0):
#       sen = "nue"
#     elif averageCompound <= -0.25:
#       sen = "neg"

#     df_audio.loc[index, feature+'_label'] = sen
  # df_audio
  # df_audio_sentences
  return df_audio

# %%
Build_quality = ["fit","feel","comfort","soft"]
sentences_with_Build=breakSentences(build_quality)
sentences_with_Build
# Out:
#                                            reviewText
# 0   [I'm paranoid about putting these in the seat ...
# 1   [They fit better and they do a much better job...
# 2   [If you're not listening to music and just com...
# 3   [When you are flying, especially if you fly a ...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                                                  []
# 9   [This may sound odd (to have a headset on with...
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18                                                 []

# %%
Battery_quality = ["long lasting","battery","but"]
sentences_with_Battery=breakSentences(Battery_quality)
sentences_with_Battery
# Out:
#                                            reviewText
# 0   [They aren't as good as similarly-priced studi...
# 1   [I have tried to "stretch" them, but they alwa...
# 2                                                  []
# 3   [I could hear the person in the next seat bett...
# 4                                                  []
# 5                                                  []
# 6   [A big plus is the way only one battery at the...
# 7   [Not as immersive and noise-cancelling as othe...
# 8                                                  []
# 9   [I'm not an expert, but I'm satisfied with the...
# 10                                                 []
# 11  [The only problem is the large size of the hea...
# 12  [This item gets two stars instead of one becau...
# 13  [Only slight negative is that I've worn headse...
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18  [I'm not an audiophile by any means, but the s...

# %%
Audio_quality = ["sound","quality","immersive"]
sentences_with_Audio=breakSentences(Audio_quality)
sentences_with_Audio
# Out:
#                                            reviewText
# 0   [Basically, in a quiet environment these sound...
# 1   [They still have good sound quality, and cut n...
# 2                                                  []
# 3   [The loud, constant background sound in airpla...
# 4   [When you turn in on in an environment where i...
# 5                                                  []
# 6   [It is advertised as providing 70% noise reduc...
# 7   [Not as immersive and noise-cancelling as othe...
# 8                                                  []
# 9   [Sound quality of the headset (noise canceling...
# 10                                                 []
# 11                                                 []
# 12  [One program I listened to had such a low base...
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18  [I'm not an audiophile by any means, but the s...

# %%
# load the model from disk
# filename = '/content/serialize_sentiment_model.pkl'
filename = '../Ml models/serialize_sentiment_model.pkl'
loaded_pipeline = pickle.load(open(filename,'rb'))
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.22.2.post1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.22.2.post1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator LinearSVC from version 0.22.2.post1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator Pipeline from version 0.22.2.post1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
sentiment(sentences_with_Battery,"Battery")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-198-4517168b7683> in <module>
# ----> 1 sentiment(sentences_with_Battery,"Battery")
#
# <ipython-input-190-52a7c1c07a68> in sentiment(sentenceArray, feature)
#      13     else:
#      14         prdict = loaded_pipeline.predict(row['reviewText'])
# ---> 15         df_audio.loc[index, feature+'_label'] = prdict
#      16 #     df_audio_sentences['scores'] = df_audio_sentences[feature+'_sen'].apply(lambda audio_sen: sid.polarity_scores(str(audio_sen)))
#      17 #     df_audio_sentences['compound']  = df_audio_sentences['scores'].apply(lambda score_dict: score_dict['compound'])
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     669             key = com.apply_if_callable(key, self.obj)
#     670         indexer = self._get_setitem_indexer(key)
# --> 671         self._setitem_with_indexer(indexer, value)
#     672
#     673     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1016
#    1017                     if len(labels) != len(value):
# -> 1018                         raise ValueError(
#    1019                             "Must have equal len keys and value "
#    1020                             "when setting with an iterable"
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
sentiment(sentences_with_Audio,"Audio")
# Out:
#                                            reviewText  \
# 0   [Basically, in a quiet environment these sound...
# 1   [They still have good sound quality, and cut n...
# 2                                                  []
# 3   [The loud, constant background sound in airpla...
# 4   [When you turn in on in an environment where i...
# 5                                                  []
# 6   [It is advertised as providing 70% noise reduc...
# 7   [Not as immersive and noise-cancelling as othe...
# 8                                                  []
# 9   [Sound quality of the headset (noise canceling...
# 10                                                 []
# 11                                                 []
# 12  [One program I listened to had such a low base...
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18  [I'm not an audiophile by any means, but the s...
#
#                   Audio_label
# 0                  [pos, neu]
# 1                       [neu]
# 2                          NA
# 3   [neu, neu, neu, neu, neu]
# 4                       [neu]
# 5                          NA
# 6                  [neu, neu]
# 7                       [neu]
# 8                          NA
# 9                  [neu, neu]
# 10                         NA
# 11                         NA
# 12                      [neu]
# 13                         NA
# 14                         NA
# 15                         NA
# 16                         NA
# 17                         NA
# 18                 [neu, neu]

# %%
sentiment(sentences_with_Build,"Build")
# Out:
#                                            reviewText Build_label
# 0   [I'm paranoid about putting these in the seat ...  [neu, neu]
# 1   [They fit better and they do a much better job...       [neu]
# 2   [If you're not listening to music and just com...       [neu]
# 3   [When you are flying, especially if you fly a ...       [pos]
# 4                                                  []          NA
# 5                                                  []          NA
# 6                                                  []          NA
# 7                                                  []          NA
# 8                                                  []          NA
# 9   [This may sound odd (to have a headset on with...       [neu]
# 10                                                 []          NA
# 11                                                 []          NA
# 12                                                 []          NA
# 13                                                 []          NA
# 14                                                 []          NA
# 15                                                 []          NA
# 16                                                 []          NA
# 17                                                 []          NA
# 18                                                 []          NA

# %%
print(prdict);
c=0
for item in x:
    print('|| '+prdict[c]+' || >',x[c],'\n')
    c=c+1;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-163-9d51f8bcd467> in <module>
# ----> 1 print(prdict);
#       2 c=0
#       3 for item in x:
#       4     print('|| '+prdict[c]+' || >',x[c],'\n')
#       5     c=c+1;
#
# NameError: name 'prdict' is not defined
